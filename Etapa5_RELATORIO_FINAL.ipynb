# %%
Relatório Final

# %% [markdown]
# # RELATÓRIO FINAL — Previsão de Preço de Carros Usados
# **Etapa 5 — Relatório Final e Apresentação**
#
# ---
#
# ## Resumo Executivo
#
# A precificação de veículos usados é um processo complexo, geralmente baseado em referências genéricas como tabela FIPE, percepção de valor de revendedores e análises subjetivas das condições do carro. O objetivo deste projeto foi construir um modelo preditivo capaz de **estimar o preço de venda de carros usados com base em características reais dos veículos**, utilizando técnicas de Machine Learning e análise estatística.
#
# O dataset utilizado contém informações de **2.520 veículos**, incluindo atributos como ano de fabricação, quilometragem, combustível, opcionais, motorização, marca e valor final de venda.
#
# Na etapa inicial, desenvolvemos um modelo baseline utilizando **Regressão Linear**, que alcançou:
#
# - **R² na validação**: **0.6987 (~70% da variação explicada)**
# - **RMSE**: **R$ 14.325,58**
# - **MAE**: **R$ 8.154,25**
#
# Os resultados indicam que o modelo já consegue estimar o valor de venda com precisão razoável, dentro de uma margem média de erro de aproximadamente **R$ 8 mil**.
#
# Com isso, estabelecemos um nível mínimo de desempenho (baseline) que agora serve como referência para modelos mais avançados — como Random Forest e XGBoost — previstos para otimização final.
#
# ---
#
# ---
#
# ## Introdução
#
# ### Problema de negócio
#
# Precificar corretamente um carro usado é determinante para evitar prejuízos e negociações injustas. Revendedores frequentemente subestimam ou superestimam valores, gerando:
#
# - Perda de competitividade
# - Redução de margem de lucro
# - Aumento de estoque parado
# - Dificuldade de tomada de decisão baseada em dados
#
# Assim, o problema de negócio deste projeto é:
#
# > **Prever o valor ideal de venda de um carro usado com base em suas características reais.**
#
# ---
#
# ### Objetivo Geral
#
# Construir e validar um modelo de Machine Learning capaz de prever com precisão o preço de venda de carros usados.
#
# ### Objetivos específicos
#
# - Tratar e padronizar dados categóricos e numéricos
# - Criar um baseline inicial
# - Avaliar o modelo em dados separados de validação
# - Identificar principais fatores que impactam preço
# - Reduzir margem de erro na precificação
#
# ---
#
# ### Metodologia utilizada
#
# Foi adotado o pipeline completo para ML:
#
# 1. Entendimento do problema
# 2. EDA — análise exploratória
# 3. Tratamento de missing values
# 4. Codificação e normalização
# 5. Divisão dos dados em treino, validação e teste
# 6. Criação do baseline
# 7. Avaliação por métricas adequadas
# 8. Preparação para otimização de modelos
#
# Todas as etapas foram executadas via Python, utilizando bibliotecas: Pandas, sklearn, Seaborn, Matplotlib e Joblib.
#
# ---
#
# ---
#
# ## Exploração dos Dados (EDA)
#
# ### Descrição do dataset
#
# Dataset: `used_cars_price.csv`
# Quantidade total: **2.520 linhas**
# Alvo do modelo: `price_brl`
#
# Principais colunas encontradas:
#
# | Variáveis numéricas       | Variáveis categóricas        | Variáveis binárias |
# |--------------------------|------------------------------|--------------------|
# | ano, km_rodados          | marca, modelo, combustivel    | air_conditioning   |
# | cilindradas              | cor, cambio                    | imported           |
# | potencia_motor           | tipo_veiculo                   | abs_brakes         |
#
# ---
#
# ### Estatísticas descritivas observadas
#
# #### Variáveis numéricas
# - Distribuição de anos concentrada entre **2013 e 2024**
# - Quilometragem variando entre **0 e ~250.000km**
# - Preços variando entre **R$ 20.000 a R$ 500.000+**
#
# #### Variáveis categóricas
# - Alto volume de modelos populares
# - Presença significativa de veículos importados
# - Maior frequência de carros a gasolina/flex
#
# ---
#
# ### Descobertas da EDA
#
# 🔺 O que valoriza veículos
# - Motorizações acima de 1.8
# - Veículos híbridos e elétricos
# - Sunroof
# - Sensores de estacionamento
# - Automáticos
# - Importados
#
# 🔻 O que desvaloriza o carro
# - Alto quilometragem
# - Combustível etanol exclusivamente
# - Versões de entrada sem opcionais
#
# Esses achados reforçam tendências conhecidas do mercado automotivo.
#
# ---
#
# ### Visualizações geradas
#
# 1. Histogramas das variáveis numéricas
# 2. Gráficos de dispersão VALOR x KM
# 3. Boxplots mostrando desvalorização por combustível
# 4. Heatmap de correlação com target
#
# Principais insights visualizados:
#
# **Relação negativa entre quilometragem e preço**
# **Correlação positiva entre ano de fabricação e preço**
# **Combustível etanol com forte tendência de queda**
#
# ---
#
# ---
#
# ## Pré-processamento dos Dados
#
# ### Tratamento de valores ausentes
#
# Aplicado:
#
# - Mediana → atributos numéricos
# - Moda → atributos categóricos
#
# Justificativa:
#
# ✔ Evita criação de valores irreais
# ✔ Mantém distribuição original
# ✔ Evita perda de registros
#
# ---
#
# ### Tratamento de outliers
#
# - Outliers mantidos inicialmente
# - Justificativa:
#
# > O preço de carros tem variações extremas reais (blindados, elétricos, top de linha).
#
# Por isso, remover valores altos afetaria representatividade.
#
# ---
#
# ### Feature Engineering aplicada
#
# ✔ Conversão de variáveis binárias (Sim/Não → 1/0)
#
# Colunas:
#
# - air_conditioning
# - power_steering
# - imported
# - sunroof
# - parking_sensors
#
# ✔ One hot encoding aplicado em marcas, modelos e combustíveis
#
# Resultado final:
#
# > dataset expandido para dezenas de dimensões úteis
#
# ---
#
# ### Transformações aplicadas
#
# - Pré-processamento implementado diretamente no dataframe
# - Gerado dataset `df_model` preparado para modelagem
#
# ---
#
# ---
#
# ## Modelagem — Baseline
#
# Modelo utilizado:
# **Regressão Linear (LinearRegression)**
#
# ### Métricas obtidas
#
# Tabela comparativa:
#
# | Métrica                | Treino (60%)             | Validação (20%)             |
# |-----------------------|--------------------------|-----------------------------|
# | R²                    | 0.6585                   | **0.6987** (~70%)           |
# | RMSE                  | R$ 15.587,13             | **R$ 14.325,58**            |
# | MAE                   | R$ 7.823,72              | **R$ 8.154,25**             |
#
# ---
#
# ### Análise dos resultados
#
# Um modelo simples explicou ~70% do preço real
# Margem de erro aproximada de R$ 8 mil
# Indica relação linear presente nos dados
# Validação melhor que treino → sem overfitting
#
# Isso posiciona a Regressão Linear como um “piso” comparativo.
#
# ---
#
# ### Seleção do modelo final da etapa
# Nesta etapa o modelo final assumido foi:
#
# > **Regressão Linear — Modelo Baseline**
#
# Porque:
#
# ✔ Estável
# ✔ Generalizou bem sem overfit
# ✔ Fácil interpretabilidade
#
# ---
#
# ---
#
# ## Otimização — Preparação Etapa Final
#
# Modelos selecionados para evolução:
#
# 1. **Random Forest Regressor**
# 2. **XGBoost Regressor**
# 3. **Lasso/Ridge** (refinamento regularizado)
#
# **Objetivos de tuning definidos:**
# - Aumentar R² ≥ 0.75
# - Reduzir RMSE para **~R$ 10.000**
# - Reduzir MAE para **~R$ 6.500**
#
# ### Técnicas a serem aplicadas
#
# - RandomizedSearchCV
# - GridSearchCV
# - Feature Importance
# - SHAP values (para interpretabilidade)
#
# ---
#
# ---
#
# ## Conclusões
#
# ### Resultados alcançados
#
# 🟢 Modelo baseline criado com boa generalização
# 🟢 Entendimento real do mercado automotivo
# 🟢 Métricas sólidas para uma primeira solução
#
# ---
#
# ### Limitações do modelo
#
# - Linearidade pode não capturar relações complexas
# - Diferença grande entre carros de luxo x populares
# - Armazenamento de outliers prejudica previsões extremas
#
# ---
#
# ### Possíveis melhorias futuras
#
# Ajuste por cluster automotivo
# Ex.: Sedans, SUVs, pick-ups, esportivos separados
#
# Preço regionalizado
# Ex.: estados com carros mais valorizados
#
# Redução de multicolinearidade
# Ex.: ano x quilometragem têm relação dependente
#
# Deploy do modelo:
# - API local
# - Painel de consulta de preços
# - Integração com banco de dados
#
# ---
#
# ### Lições aprendidas
#
# Melhoras simples em pré-processamento aumentam desempenho
# Escolha das métricas faz diferença no julgamento
# Dados categóricos têm maior peso no preço final
# Sem baseline não há parâmetro de evolução
#
# ---
#
# ---
#
# ## Referências
#
# - Documentação Sklearn
# https://scikit-learn.org/
#
# - Pandas
# https://pandas.pydata.org/
#
# - Seaborn visual analytics
# https://seaborn.pydata.org/
#
# - Artigos sobre desvalorização automotiva no Brasil
# KBB – Kelley Blue Book
# FIPE — Fundação Instituto de Pesquisas Econômicas
#
# ---
#
# > Documento final construído com base nos resultados obtidos em código Python, utilizando dataset real de 2.520 registros.
